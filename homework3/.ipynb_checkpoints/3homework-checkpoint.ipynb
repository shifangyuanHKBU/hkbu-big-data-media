# %%
# !pip install pandas
# Out:
# ...
# You are using pip version 9.0.1, however version 9.0.3 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.

# %%
import pandas as pd

# %%
df= pd.read_csv("doubanmovie.csv")

# %%
df
# Out:
#             title  number of comments  rating
# 0          肖申克的救赎              986463     9.6
# 1            霸王别姬              716546     9.5
# 2         这个杀手不太冷              930439     9.4
# 3            阿甘正传              791184     9.4
# 4            美丽人生              462337     9.5
# 5            千与千寻              740158     9.2
# 6           泰坦尼克号              730689     9.2
# 7          辛德勒的名单              421478     9.4
# 8            盗梦空间              833212     9.3
# 9          机器人总动员              546397     9.3
# 10          海上钢琴师              644352     9.2
# 11        三傻大闹宝莱坞              746743     9.2
# 12        忠犬八公的故事              512922     9.2
# 13         放牛班的春天              499397     9.2
# 14      大话西游之大圣娶亲              544854     9.2
# 15             教父              375842     9.2
# 16             龙猫              460895     9.1
# 17          楚门的世界              514613     9.1
# 18             熔炉              298381     9.2
# ...

# %%
# !pip install matplotlib
# Out:
# ...
#     100% |████████████████████████████████| 13.7MB 117kB/s eta 0:00:01
# ...
#   Using cached cycler-0.10.0-py2.py3-none-any.whl
# ...
#     100% |████████████████████████████████| 112kB 12.1MB/s ta 0:00:01
# ...
#   Using cached pyparsing-2.2.0-py2.py3-none-any.whl
# ...
# You are using pip version 9.0.1, however version 9.0.3 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.

# %%
aa = df['rating'].hist(bins=10)

# %% [markdown]
# As we can see,the rating between 8.6-8.8 have a highest ratio in total 250 movies and the minimum ratio of the rating is over 9.2points.Most of the movies are in the 8.6 area and lower than 9.2 area.

# %%
aa = df['number of comments'].hist(bins=10)

# %% [markdown]
# Almost 120movies have comments under 200000 and there is no movie have comments over 100000,even it is the very high rating movie.There have a clearly decrease when comments over 400000.

# %%
df1 = df[:100]

# %%
df1
# Out:
#          title  number of comments  rating
# 0       肖申克的救赎              986463     9.6
# 1         霸王别姬              716546     9.5
# 2      这个杀手不太冷              930439     9.4
# 3         阿甘正传              791184     9.4
# 4         美丽人生              462337     9.5
# 5         千与千寻              740158     9.2
# 6        泰坦尼克号              730689     9.2
# 7       辛德勒的名单              421478     9.4
# 8         盗梦空间              833212     9.3
# 9       机器人总动员              546397     9.3
# 10       海上钢琴师              644352     9.2
# 11     三傻大闹宝莱坞              746743     9.2
# 12     忠犬八公的故事              512922     9.2
# 13      放牛班的春天              499397     9.2
# 14   大话西游之大圣娶亲              544854     9.2
# 15          教父              375842     9.2
# 16          龙猫              460895     9.1
# 17       楚门的世界              514613     9.1
# 18          熔炉              298381     9.2
# 19        乱世佳人              293104     9.2
# 20        星际穿越              542289     9.2
# ...

# %%
df1.sort_values(by='rating', ascending=False).head(10)
# Out:
#       title  number of comments  rating
# 0    肖申克的救赎              986463     9.6
# 41     控方证人              105563     9.6
# 4      美丽人生              462337     9.5
# 1      霸王别姬              716546     9.5
# 2   这个杀手不太冷              930439     9.4
# 7    辛德勒的名单              421478     9.4
# 3      阿甘正传              791184     9.4
# 26     十二怒汉              186540     9.4
# 8      盗梦空间              833212     9.3
# 43      海豚湾              192729     9.3

# %%
df1.sort_values(by='number of comments', ascending=False).head(10)
# Out:
#       title  number of comments  rating
# 0    肖申克的救赎              986463     9.6
# 2   这个杀手不太冷              930439     9.4
# 8      盗梦空间              833212     9.3
# 3      阿甘正传              791184     9.4
# 11  三傻大闹宝莱坞              746743     9.2
# 5      千与千寻              740158     9.2
# 6     泰坦尼克号              730689     9.2
# 1      霸王别姬              716546     9.5
# 77     让子弹飞              661407     8.7
# 10    海上钢琴师              644352     9.2

# %% [markdown]
# The two graphs above show that the rating and comments of a movie is not necessarily have direct proportional,in chinses we called "叫好不卖座".For example,the movie called 控方证人 have 9.6rating,it is really high in Douban movie list,but the number of comments only have 105563,compared with other 9.6rating movies,the comments number have decreased almost 80000.However,肖申克的救赎 have both most high rating and maximum number of comments.
